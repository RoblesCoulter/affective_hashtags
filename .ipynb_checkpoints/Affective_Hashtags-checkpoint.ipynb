# %%
## NowPlaying Cultural Sentiment Data
"""
cs_header = ["hashtag", "AFINN_min", "AFINN_max", "AFINN_sum", "AFINN_avg", "OpinionLex_min", "OpinionLex_max", "OpinionLex_sum", "OpinionLex_avg", "Sentistrength_min", "Sentistrength_max", "Sentistrength_sum", "Sentistrength_avg", "Vader_min", "Vader_max", "Vader_sum", "Vader_avg", "SentimentHashtag_min", "SentimentHashtag_max", "SentimentHashtag_sum", "SentimentHashtag_avg"]
np_cs = pd.read_csv('np_cultural_sentiment.csv',names = cs_header)
"""
#IMPORTING Cultural Sentiment Data to MongoDB
"""
np_cs_json = json.loads(np_cs.to_json(orient="records"))
db.cultural_sentiment.drop()
db.cultural_sentiment.insert_many(np_cs_json)
"""
## Transformation of NowPlaying Cultural Tweets to DataframeStructure
"""
output = []
with open("np_cultural.json") as f:
    for line in f:     
        output.append(json.loads(line))
np_c = pd.DataFrame(output)
"""
#IMPORTING Cultural Tweets to MongoDB
"""
db.cultural_tweet.drop()
records = json.loads(np_c.T.to_json()).values()
db.cultural_tweet.insert_many(records)
"""

## Transformation and Importing of Playlist Data from NowPlaying to MongoDB
"""
np_pl = pd.read_csv("playlist.csv", names=["playlist_id","track_id","playlist_name"])
np_pl_json = json.loads(np_pl.to_json(orient="records"))
db.playlist.drop()
db.playlist.insert_many(np_pl_json)
"""

# %% [markdown]
# # CULTURAL #NOWPLAYING DATA
# *********************************
#
# This dataset contains data describing the listening events of users (extracted from the #nowplaying dataset), the emotion extracted from the hashtags used in the according tweets and information about the location of the user.
#
#
# TWITTER AND TRACK DATA
# -------------------------------
# The data regarding the listening events is contained in np_cultural.zip and is encoded as json. It holds the following information:
#
# - id: the id of the underlying tweet [*]
# - user_id: the id of the user who sent the tweet (MD5 of it)
# - user_lang: The BCP 47 code for the user’s self-declared user interface language. [*]
# - user_time_zone: [*]
# - text: actual content of the tweet [*]
# - tweet_lang: language of the tweet (as detected by Twitter; BCP 47 language identifier corresponding to the machine-detected language of the Tweet text, or und if no language could be detected.) [*]
# - geo: Deprecated version of coordinates (however, we deal with data stemming from before this API change, therefore we still include it; cf. coordinates for a description)
# - coordinates: Represents the geographic location of this Tweet as reported by the user or client application. The inner coordinates array is formatted as geoJSON (longitude first, then latitude). [*]
# - place: When present, indicates that the tweet is associated (but not necessarily originating from) a Place. [*]
# - created_at: time the tweet was sent. [*]
# - source: Utility used to post the Tweet, as an HTML-formatted string. [*]
# - track_title: title of the track the user tweeted about
# - track_id: the unique id of the track (from #nowplaying dataset)
# - artist_name: name of artist performing the track
# - artist_id: the unique id of the artist (from #nowplaying dataset)
# - hashtags: list of hashtags used in the tweet.
#
# [*] for further information about the information gathered from Twitter, please consult https://dev.twitter.com/overview/api/tweets
#
# Please note that we do only add key-value pairs for geo/coordinates/place information if this information was provided by the Twitter API (i.e., missing keys signal that this information is not available for the given tweet).
#
#
# SENTIMENT DATA
# -------------------------------
# The data regarding the hashtag's sentiment (if any could be obtained) is contained in np_cultural_sentiment.csv and is formatted as csv. The sentiment score was obtained by applying a set of well-known sentiment dictionaries. The sentiment scores are scaled between 0 and 1 (very negative to very positive). For each dictionary, we list the minimum, maximum, sum and average sentiment score across all hashtags used within every tweet (most tweets only feature a single hashtag we can assign a sentiment value to)
# It contains the following information (in this particular order):
# - name of the hashtag
# - AFINN dictionary (min, max, sum, avg)
# - Opinion Lexicon (min, max, sum, avg)
# - Sentistrength Lexicon (min, max, sum, avg)
# - Vader (min, max, sum, avg)
# - Sentiment Hashtag Lexicon (min, max, sum, avg)
#
#
# Please note that we only added hashtags for which we could obtain a sentiment value from at least one sentiment dictionary.

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import numpy as np 
import json
import csv
import pprint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from difflib import SequenceMatcher

# %%
#Call Mongo Instance
client = MongoClient()
db = client.now_playing

#Spotify Instance
client_credentials_manager = SpotifyClientCredentials(client_id="7736d10450e04c5f9e302bb07a4f6cf7", client_secret="a11e29bc5c324ddeb19fc6249d303814",)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ### Importing the MusicBrainz Mapping of artists and tracks and tracks from cultural dataset
#
# `mongoimport -d now_playing -c mb_tracks --type csv --file mb_tracks.csv --fields "np_id,mb_track_id"`
#
# `mongoimport -d now_playing -c mb_artists --type csv --file mb_artists.csv --fields "np_id,mb_artist_id"`
#
# `mongoimport -d now_playing -c np_cultural_mb_tracks --type csv --file np_cultural_mb_tracks.csv --headerline
# `

# %%
user_ids = db.cultural_tweet.distinct("user_id")
type(user_ids)
# Out:
# list

# %%
#db.cultural_tweet.find({"hashtag": "nobeats"})
user_tweets = db.cultural_tweet.find({"user_id": '1c10f9788fdcc4baf6cf6a2631fe78bc12102418'})
#TOTAL Number of Tweets
print("Total number of Tweets: "+ str(db.cultural_tweet.find({}).count()))
print("Total number of Songs: " + str(len(db.cultural_tweet.distinct("track_title"))))
#Get Distinct User Ids
print("Total number of Users: " + str(len(user_ids)))
# Out:
# Total number of Tweets: 564301
# Total number of Songs: 39776
# Total number of Users: 9431

# %%
first = user_ids[0]
user_songs = db.cultural_tweet.find({"user_id": first})
initial_song = user_songs[0]
initial_date = initial_song["created_at"]

# %%
#db.mb_tracks.find({"np_id": initial_song["track_id"]}).count()
#for song in user_songs:
#    print(str(song["track_title"]))
#    print(str(song["track_id"]))
    
print(len(db.cultural_tweet.distinct("track_id")))
print(len(db.cultural_tweet.distinct("track_title")))
# Out:
# 51045
# 39776

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()
def convertMillis(millis):
     seconds = (millis/1000)%60
     minutes = (millis/(1000*60))%60
     return str(int(minutes)) + ":" +str(int(seconds))

# %%
"""
search_query = initial_song["track_title"].lower() +" "+ initial_song["artist_name"].lower()
results = sp.search(q=search_query,limit=5)
print("Looking for: "+search_query)
print("Querying...")
for track in results["tracks"]["items"]:
    artist_names = list(map(lambda x: x["name"],track["artists"]))
    print(" ".join(artist_names))
    print("Found: " + str(track["name"]) + " "+str(track["artists"][0]["name"]))
    print(convertMillis(track["duration_ms"]))
    result_matcher = track["name"].lower() + " " + track["artists"][0]["name"].lower()
    print("Similarity Score: " + str((similar(search_query, result_matcher))))
"""
# Out:
# '\nsearch_query = initial_song["track_title"].lower() +" "+ initial_song["artist_name"].lower()\nresults = sp.search(q=search_query,limit=5)\nprint("Looking for: "+search_query)\nprint("Querying...")\nfor track in results["tracks"]["items"]:\n    artist_names = list(map(lambda x: x["name"],track["artists"]))\n    print(" ".join(artist_names))\n    print("Found: " + str(track["name"]) + " "+str(track["artists"][0]["name"]))\n    print(convertMillis(track["duration_ms"]))\n    result_matcher = track["name"].lower() + " " + track["artists"][0]["name"].lower()\n    print("Similarity Score: " + str((similar(search_query, result_matcher))))\n'

# %%
final_result = dict()
#Get Spotify's song duration
track_list = db.cultural_tweet.distinct("track_id")
for track in track_list:
    song_name = db.cultural_tweet.find_one({"track_id": track, "duration_ms": {"$exists": False }}, {"track_title" : 1 , "artist_name": 1})
    search_query = song_name["track_title"].lower() + " " + song_name["artist_name"].lower()
    print("Querying for:" + search_query)
    search_result = sp.search(q = search_query, limit= 3, type="track")
    for t in search_result["tracks"]["items"]:
        artists = " ".join(list(map(lambda x: x["name"],t["artists"])))
        result_matcher = t["name"].lower() + " " + artists.lower()
        similarity_score = similar(search_query,result_matcher)
        if(similarity_score > 0.95):
            print("Found " + result_matcher)
            print("Similarity Score: " + str(similarity_score))
            final_result[track] = t["duration_ms"]
            break
# Out:
# Querying for:intuition jewel
# Found intuition jewel
# Similarity Score: 1.0
# Querying for:jesus queen
# Found jesus queen
# Similarity Score: 1.0
# Querying for:dont go yazoo
# Querying for:el jardin prohibido alex bueno
# Querying for:deus the sugarcubes
# Found deus the sugarcubes
# Similarity Score: 1.0
# Querying for:clementine james last
# Querying for:im not jesus apocalyptica
# Querying for:secret love james last
# Querying for:ella ella fitzgerald
# Querying for:catacombs il giardino violetto
# Querying for:gangsta kat dahlia
# Found gangsta kat dahlia
# Similarity Score: 1.0
# Querying for:symbolic death
# Found symbolic death
# Similarity Score: 1.0
# Querying for:as stevie wonder
# Found as stevie wonder
# Similarity Score: 1.0
# Querying for:scala agoria
# Found scala agoria
# Similarity Score: 1.0
# Querying for:you are my sunshine james last
# Found you are my sunshine james last
# Similarity Score: 1.0
# Querying for:the way you love me faith hill
# Found the way you love me faith hill
# Similarity Score: 1.0
# Querying for:never be the same ulrich schnauss
# Found never be the same ulrich schnauss
# Similarity Score: 1.0
# Querying for:3 birds the dead weather
# Found 3 birds the dead weather
# Similarity Score: 1.0
# Querying for:millennium anxiety wasteland
# Querying for:amapola james last
# Found amapola james last
# Similarity Score: 1.0
# Querying for:towers little mix
# Found towers little mix
# Similarity Score: 1.0
# Querying for:isaiah boar
# Found isaiah boar
# Similarity Score: 1.0
# Querying for:kosmos yob
# Found kosmos yob
# Similarity Score: 1.0
# Querying for:pretty noose soundgarden
# Found pretty noose soundgarden
# Similarity Score: 1.0
# Querying for:volare gipsy kings
# Found volare gipsy kings
# Similarity Score: 1.0
# Querying for:where do you sleep at night lynch mob
# Found where do you sleep at night lynch mob
# Similarity Score: 1.0
# Querying for:the state of madness madness of the night
# Found the state of madness madness of the night
# Similarity Score: 1.0
# Querying for:tower zola jesus
# Found tower zola jesus
# Similarity Score: 1.0
# Querying for:soul of fire witch
# Found soul of fire witch
# Similarity Score: 1.0
# Querying for:say you say me lionel richie
# Found say you, say me lionel richie
# Similarity Score: 0.9824561403508771
# Querying for:baby one more time britney spears
# Found ...baby one more time britney spears
# Similarity Score: 0.9565217391304348
# Querying for:in the air tonight phil collins
# Found in the air tonight phil collins
# Similarity Score: 1.0
# Querying for:revelge ghosting
# Querying for:freaks french montana
# Querying for:bela lugosis dead bauhaus
# Found bela lugosi's dead bauhaus
# Similarity Score: 0.9803921568627451
# Querying for:bye bye blackbird james last
# Querying for:bitter pill mötley crüe
# Querying for:were taking this kylesa
# Found we're taking this kylesa
# Similarity Score: 0.9787234042553191
# Querying for:eternal life jeff buckley
# Found eternal life jeff buckley
# Similarity Score: 1.0
# Querying for:shine slowdive
# Querying for:don diablo miguel bosé
# Found don diablo miguel bosé
# Similarity Score: 1.0
# Querying for:dancing girl terry callier
# Found dancing girl terry callier
# Similarity Score: 1.0
# Querying for:this time dj antoine
# Querying for:press 2 x
# Querying for:bleed it dry alter bridge
# Found bleed it dry alter bridge
# Similarity Score: 1.0
# Querying for:take care michael henderson
# Found take care michael henderson
# Similarity Score: 1.0
# Querying for:miles miles davis
# Querying for:sunshine of your love cream
# Found sunshine of your love cream
# Similarity Score: 1.0
# Querying for:is she secretly on my side? unwoman
# Found is she secretly on my side? unwoman
# Similarity Score: 1.0
# Querying for:make it rain travis porter
# Found make it rain travis porter
# Similarity Score: 1.0
# Querying for:leaders of men joy division
# Querying for:miss you aaliyah
# Querying for:emotions twista
# Found emotions twista
# Similarity Score: 1.0
# Querying for:maybe tomorrow samantha james
# Found maybe tomorrow samantha james
# Similarity Score: 1.0
# Querying for:a closed fist makes no one happy red handed denial
# Found a closed fist makes no one happy red handed denial
# Similarity Score: 1.0
# Querying for:voodoo chile jimi hendrix
# Found voodoo chile jimi hendrix
# Similarity Score: 1.0
# Querying for:incredible cã©line dion
# Querying for:phase one and two blowback
# Querying for:ghosts japan
# Found ghosts japan
# Similarity Score: 1.0
# Querying for:locked out of heaven bruno mars
# Found locked out of heaven bruno mars
# Similarity Score: 1.0
# Querying for:earth colour haze
# Found earth colour haze
# Similarity Score: 1.0
# Querying for:trust megadeth
# Found trust megadeth
# Similarity Score: 1.0
# Querying for:new song nuclear assault
# Found new song nuclear assault
# Similarity Score: 1.0
# Querying for:pumps amy winehouse
# Querying for:get it on the power station
# Querying for:nothing metallica
# Querying for:dandy james last
# Found dandy james last
# Similarity Score: 1.0
# Querying for:do murder and lust make me a man? ordo rosarius equilibrio
# Found do murder and lust make me a man? ordo rosarius equilibrio
# Similarity Score: 1.0
# Querying for:new perspective panic! at the disco
# Querying for:police & thieves the clash
# Querying for:shes a bad mama jama carl carlton
# Querying for:too much tracer
# Found too much tracer
# Similarity Score: 1.0
# Querying for:a kind of magic queen
# Found a kind of magic queen
# Similarity Score: 1.0
# Querying for:just the way you are milky
# Found just the way you are milky
# Similarity Score: 1.0
# Querying for:out drake
# Querying for:call me the breeze lynyrd skynyrd
# Found call me the breeze lynyrd skynyrd
# Similarity Score: 1.0
# Querying for:destination venus the rezillos
# Found destination venus the rezillos
# Similarity Score: 1.0
# Querying for:sing for the moment eminem
# Found sing for the moment eminem
# Similarity Score: 1.0
# Querying for:breathe faith hill
# Found breathe faith hill
# Similarity Score: 1.0
# Querying for:funhouse in dub venus in furs
# Querying for:touch and go magazine
# Querying for:creeping death calling dead red roses
# Querying for:castle castle
# Querying for:money for nothing dire straits
# Querying for:rolling in the deep adele
# Found rolling in the deep adele
# Similarity Score: 1.0
# Querying for:no more mr nice guy alice cooper
# Found no more mr. nice guy alice cooper
# Similarity Score: 0.9846153846153847
# Querying for:cant get enough soulsearcher
# Querying for:my love justin timberlake
# Querying for:tight pants are for girls termanology
# Querying for:schools out alice cooper
# Found school's out alice cooper
# Similarity Score: 0.9795918367346939
# Querying for:red red
# Querying for:head over heels allure
# Querying for:sleep snakadaktal
# Querying for:suspect device stiff little fingers
# Querying for:immortal kid cudi
# Found immortal kid cudi
# Similarity Score: 1.0
# Querying for:first place sixteens
# Querying for:trophies drake
# Querying for:perfidia james last
# Querying for:the sun & the rainfall depeche mode
# Querying for:never gonna give you up rick astley
# Found never gonna give you up rick astley
# Similarity Score: 1.0
# Querying for:jump in the fire dee dee ramone
# Found jump in the fire dee dee ramone
# Similarity Score: 1.0
# Querying for:dark side kelly clarkson
# Found dark side kelly clarkson
# Similarity Score: 1.0
# Querying for:crow hymn eagle twin
# Found crow hymn eagle twin
# Similarity Score: 1.0
# Querying for:move ya body nina sky
# Querying for:dont leave me blackstreet
# Found don't leave me blackstreet
# Similarity Score: 0.9803921568627451
# Querying for:hey now kyle
# Querying for:demons imagine dragons
# Found demons imagine dragons
# Similarity Score: 1.0
# Querying for:dont laugh wink
# Querying for:the sad saga of the boy and the bee gun
# Querying for:ive got friends manchester orchestra
# Found i've got friends manchester orchestra
# Similarity Score: 0.9863013698630136
# Querying for:largo james last
# Querying for:zombie the cranberries
# Found zombie the cranberries
# Similarity Score: 1.0
# Querying for:love like blood love like blood
# Querying for:the edge of glory lady gaga
# Found the edge of glory lady gaga
# Similarity Score: 1.0
# Querying for:i want love the treatment
# Found i want love the treatment
# Similarity Score: 1.0
# Querying for:body bush
# Found body bush
# Similarity Score: 1.0
# Querying for:ayla ayla
# Querying for:one rainy wish jimi hendrix
# Found one rainy wish jimi hendrix
# Similarity Score: 1.0
# Querying for:if tomorrow never comes ronan keating
# Found if tomorrow never comes ronan keating
# Similarity Score: 1.0
# Querying for:stairway to heaven led zeppelin
# Found stairway to heaven led zeppelin
# Similarity Score: 1.0
# Querying for:clique kanye west
# Querying for:simple man lynyrd skynyrd
# Found simple man lynyrd skynyrd
# Similarity Score: 1.0
# Querying for:break my stride matthew wilder
# Found break my stride matthew wilder
# Similarity Score: 1.0
# Querying for:substitute ramones
# Found substitute ramones
# Similarity Score: 1.0
# Querying for:lebron james yo gotti
# Found lebron james yo gotti
# Similarity Score: 1.0
# Querying for:gun gun
# Querying for:thy kingdom come shadow project
# Found thy kingdom come shadow project
# Similarity Score: 1.0
# Querying for:dying giant conan
# Found dying giant conan
# Similarity Score: 1.0
# Querying for:language of the living dead blacklist
# Found language of the living dead blacklist
# Similarity Score: 1.0
# Querying for:listen nicole
# Querying for:story of my life one direction
# Found story of my life one direction
# Similarity Score: 1.0
# Querying for:kingston sean kingston
# Querying for:bhimas theme om
# Found bhima's theme om
# Similarity Score: 0.967741935483871
# Querying for:team lorde
# Found team lorde
# Similarity Score: 1.0
# Querying for:거짓말 bigbang
# Querying for:ready men big black
# Found ready men big black
# Similarity Score: 1.0
# Querying for:love james last
# Querying for:burn ellie goulding
# Found burn ellie goulding
# Similarity Score: 1.0
# Querying for:disciple slayer
# Found disciple slayer
# Similarity Score: 1.0
# Querying for:dont think they know chris brown
# Querying for:reaching out nero
# Found reaching out nero
# Similarity Score: 1.0
# Querying for:sham shack ut
# Querying for:beings of light alcest
# Found beings of light alcest
# Similarity Score: 1.0
# Querying for:what do i get? buzzcocks
# Found what do i get? buzzcocks
# Similarity Score: 1.0
# Querying for:clint eastwood gorillaz
# Found clint eastwood gorillaz
# Similarity Score: 1.0
# Querying for:dum dum baauer
# Found dum dum baauer
# Similarity Score: 1.0
# Querying for:monuments to ruins kalas
# Found monuments to ruins kalas
# Similarity Score: 1.0
# Querying for:you and me lifehouse
# Found you and me lifehouse
# Similarity Score: 1.0
# Querying for:my wild love the doors
# Found my wild love the doors
# Similarity Score: 1.0
# Querying for:time of the season the zombies
# Found time of the season the zombies
# Similarity Score: 1.0
# Querying for:second assault horisont
# Querying for:starships nicki minaj
# Found starships nicki minaj
# Similarity Score: 1.0
# Querying for:blow rick ross
# Querying for:event horizon whelm
# Querying for:atmosphere kaskade
# Found atmosphere kaskade
# Similarity Score: 1.0
# Querying for:kiss me sixpence none the richer
# Found kiss me sixpence none the richer
# Similarity Score: 1.0
# Querying for:chance red lorry yellow lorry
# Found chance red lorry yellow lorry
# Similarity Score: 1.0
# Querying for:707 nimrod wildfire
# Found 707 nimrod wildfire
# Similarity Score: 1.0
# Querying for:the beast the only ones
# Found the beast the only ones
# Similarity Score: 1.0
# Querying for:romeo donna summer
# Found romeo donna summer
# Similarity Score: 1.0
# Querying for:guilty bee gees
# Querying for:this is me demi lovato
# Querying for:how do i live trisha yearwood
# Querying for:eva eva
# Querying for:suddenly billy ocean
# Found suddenly billy ocean
# Similarity Score: 1.0
# Querying for:anaconda melvins
# Found anaconda melvins
# Similarity Score: 1.0
# Querying for:senses working overtime xtc
# Found senses working overtime xtc
# Similarity Score: 1.0
# Querying for:footloose kenny loggins
# Found footloose kenny loggins
# Similarity Score: 1.0
# Querying for:uptown girl westlife
# Querying for:boys dont cry the cure
# Querying for:monotonie ideal
# Querying for:we are explorers cut copy
# Found we are explorers cut copy
# Similarity Score: 1.0
# Querying for:greyhound swedish house mafia
# Found greyhound swedish house mafia
# Similarity Score: 1.0
# Querying for:ave maria michael bublé
# Found ave maria michael bublé
# Similarity Score: 1.0
# Querying for:seven hills while she sleeps
# Found seven hills while she sleeps
# Similarity Score: 1.0
# Querying for:all the above beanie sigel
# Querying for:the heart of rock and roll james last
# Querying for:8 miles high the byrds
# Querying for:one vision queen
# Found one vision queen
# Similarity Score: 1.0
# Querying for:beneath your beautiful labrinth
# Querying for:oh ludacris
# Querying for:my love westlife
# Found my love westlife
# Similarity Score: 1.0
# Querying for:hard sun eddie vedder
# Found hard sun eddie vedder
# Similarity Score: 1.0
# Querying for:madre madre del vizio
# Querying for:boom boom john lee hooker
# Found boom boom john lee hooker
# Similarity Score: 1.0
# Querying for:the reason hoobastank
# Found the reason hoobastank
# Similarity Score: 1.0
# Querying for:cum on feel the noize quiet riot
# Found cum on feel the noize quiet riot
# Similarity Score: 1.0
# Querying for:complicated angels of liberty
# Querying for:eyes harvest rain
# Querying for:promises buzzcocks
# Found promises buzzcocks
# Similarity Score: 1.0
# Querying for:green day green day
# Querying for:us z
# Querying for:we i
# Querying for:runaway runaway
# Querying for:silence silence
# Querying for:rapture blondie
# Found rapture blondie
# Similarity Score: 1.0
# Querying for:dust in the wind kansas
# Found dust in the wind kansas
# Similarity Score: 1.0
# Querying for:sudahi perih ini dmasiv
# Found sudahi perih ini d’masiv
# Similarity Score: 0.9787234042553191
# Querying for:when you believe mariah carey
# Querying for:big black train bain wolfkind
# Found big black train bain wolfkind
# Similarity Score: 1.0
# Querying for:something inside me has died kommunity fk
# Querying for:you dont know my name alicia keys
# Found you don't know my name alicia keys
# Similarity Score: 0.9850746268656716
# Querying for:fire lances of the ancient hyperzephyrians the sword
# Found fire lances of the ancient hyperzephyrians the sword
# Similarity Score: 1.0
# Querying for:little jeannie elton john
# Found little jeannie elton john
# Similarity Score: 1.0
# Querying for:scumbag stonehelm
# Querying for:copper sunset aardvark
# Found copper sunset aardvark
# Similarity Score: 1.0
# Querying for:wont talk about it beats international
# Querying for:lady dangelo
# Found lady d'angelo
# Similarity Score: 0.96
# Querying for:i just cant get enough herd & fitz
# Querying for:blinded blinded
# Querying for:teach me tonight phoebe snow
# Found teach me tonight phoebe snow
# Similarity Score: 1.0
# Querying for:nobody knows destroy all monsters
# Found nobody knows destroy all monsters
# Similarity Score: 1.0
# Querying for:of the wild drowning horse
# Querying for:civil war civil war
# Querying for:bad things jace everett
# Found bad things jace everett
# Similarity Score: 1.0
# Querying for:the uninvited alter bridge
# Found the uninvited alter bridge
# Similarity Score: 1.0
# Querying for:if if
# Querying for:eleanor rigby the beatles
# Querying for:something that i said the ruts
# Found something that i said the ruts
# Similarity Score: 1.0
# Querying for:good good night roscoe dash
# Found good good night roscoe dash
# Similarity Score: 1.0
# Querying for:its my life bon jovi
# Found it's my life bon jovi
# Similarity Score: 0.975609756097561
# Querying for:doctor my eyes jackson browne
# Found doctor my eyes jackson browne
# Similarity Score: 1.0
# Querying for:sexy people pitbull
# Querying for:maneater nelly furtado
# Found maneater nelly furtado
# Similarity Score: 1.0
# Querying for:u pearl jam
# Querying for:mailman soundgarden
# Found mailman soundgarden
# Similarity Score: 1.0
# Querying for:parisienne walkways gary moore
# Found parisienne walkways gary moore
# Similarity Score: 1.0
# Querying for:white wedding billy idol
# Querying for:black sabbath black sabbath
# Querying for:just kickin it xscape
# Found just kickin' it xscape
# Similarity Score: 0.9767441860465116
# Querying for:shakedown bob seger
# Found shakedown bob seger
# Similarity Score: 1.0
# Querying for:together again janet jackson
# Found together again janet jackson
# Similarity Score: 1.0
# Querying for:waiting for a girl like you foreigner
# Found waiting for a girl like you foreigner
# Similarity Score: 1.0
# Querying for:right now david guetta
# Querying for:si ese tiempo pudiera volver emmanuel
# Found si ese tiempo pudiera volver emmanuel
# Similarity Score: 1.0
# Querying for:they dont know rico love
# Found they don't know rico love
# Similarity Score: 0.9795918367346939
# Querying for:apocalypse wasteland
# Querying for:the boy in the picture the seahorses
# Querying for:blood in this moment
# Found blood in this moment
# Similarity Score: 1.0
# Querying for:let her go passenger
# Found let her go passenger
# Similarity Score: 1.0
# Querying for:more than i can say for you ice dragon
# Found more than i can say for you ice dragon
# Similarity Score: 1.0
# Querying for:vengeance falls trivium
# Found vengeance falls trivium
# Similarity Score: 1.0
# Querying for:waka flocka flame waka flocka flame
# Querying for:call me maybe carly rae jepsen
# Found call me maybe carly rae jepsen
# Similarity Score: 1.0
# Querying for:if i die young the band perry
# Found if i die young the band perry
# Similarity Score: 1.0
# Querying for:cosmic cruiser x mage
# Found cosmic cruiser x mage
# Similarity Score: 1.0
# Querying for:fluch der fluch
# Querying for:my sharona hammerfall
# Found my sharona hammerfall
# Similarity Score: 1.0
# Querying for:train train
# Querying for:all nightmare long metallica
# Found all nightmare long metallica
# Similarity Score: 1.0
# Querying for:give life back to music daft punk
# Found give life back to music daft punk
# Similarity Score: 1.0
# Querying for:maybe janis joplin
# Found maybe janis joplin
# Similarity Score: 1.0
# Querying for:smooth smooth
# Querying for:motion and heart orchestral manoeuvres in the dark
# Querying for:adalita james last
# Querying for:i will walk you home the adverts
# Found i will walk you home the adverts
# Similarity Score: 1.0
# Querying for:freebola glup!
# Querying for:hotel california gipsy kings
# Querying for:be lenny kravitz
# Found be lenny kravitz
# Similarity Score: 1.0
# Querying for:shine shine
# Querying for:free bird lynyrd skynyrd
# Found free bird lynyrd skynyrd
# Similarity Score: 1.0
# Querying for:blood is the price of glory ensiferum
# Found blood is the price of glory ensiferum
# Similarity Score: 1.0
# Querying for:star max urban
# Querying for:take it easy eagles
# Found take it easy eagles
# Similarity Score: 1.0
# Querying for:lady rain indecent obsession
# Found lady rain indecent obsession
# Similarity Score: 1.0
# Querying for:one in a million bosson
# Querying for:bigbang bigbang
# Querying for:share g.i.v.e.
# Querying for:death alien sex fiend
# Found death alien sex fiend
# Similarity Score: 1.0
# Querying for:as long as you love me backstreet boys
# Found as long as you love me backstreet boys
# Similarity Score: 1.0
# Querying for:dont stop me now queen
# Found don't stop me now queen
# Similarity Score: 0.9777777777777777
# Querying for:royals lorde
# Found royals lorde
# Similarity Score: 1.0
# Querying for:waiting for a star to fall boy meets girl
# Found waiting for a star to fall boy meets girl
# Similarity Score: 1.0
# Querying for:lose to win fantasia
# Found lose to win fantasia
# Similarity Score: 1.0
# Querying for:just one hoobastank
# Found just one hoobastank
# Similarity Score: 1.0
# Querying for:let her cry hootie & the blowfish
# Found let her cry hootie & the blowfish
# Similarity Score: 1.0
# Querying for:breathe anna lunoe
# Querying for:bassline the get along gang
# Querying for:she makes me go sean paul
# Querying for:waiting for superman daughtry
# Found waiting for superman daughtry
# Similarity Score: 1.0
# Querying for:a strange day the cure
# Querying for:iced earth iced earth
# Querying for:here in my heart plus one
# Found here in my heart plus one
# Similarity Score: 1.0
# Querying for:me! i disconnect from you gary numan
# Querying for:orchid dreaming big electric cat
# Found orchid dreaming big electric cat
# Similarity Score: 1.0
# Querying for:babe im gonna leave you led zeppelin
# Found babe i'm gonna leave you led zeppelin
# Similarity Score: 0.9863013698630136
# Querying for:adams apple aerosmith
# Found adam's apple aerosmith
# Similarity Score: 0.9767441860465116
# Querying for:you bad religion
# Found you bad religion
# Similarity Score: 1.0
# Querying for:funhouse funhouse
# Querying for:mockingbird eminem
# Found mockingbird eminem
# Similarity Score: 1.0
# Querying for:live for the night krewella
# Found live for the night krewella
# Similarity Score: 1.0
# Querying for:stay tyrese
# Found stay tyrese
# Similarity Score: 1.0
# Querying for:drunk with power discharge
# Found drunk with power discharge
# Similarity Score: 1.0
# Querying for:when you say nothing at all ronan keating
# Found when you say nothing at all ronan keating
# Similarity Score: 1.0
# Querying for:once in a lifetime talking heads
# Found once in a lifetime talking heads
# Similarity Score: 1.0
# Querying for:operation blade public domain
# Querying for:must b the music de la soul
# Querying for:girl anachronism the dresden dolls
# Found girl anachronism the dresden dolls
# Similarity Score: 1.0
# Querying for:push tracer
# Found push tracer
# Similarity Score: 1.0
# Querying for:glow madcon
# Found glow madcon
# Similarity Score: 1.0
# Querying for:love missile sigue sigue sputnik
# Querying for:roundabout yes
# Querying for:til i hear it from you gin blossoms
# Found til i hear it from you gin blossoms
# Similarity Score: 1.0
# Querying for:monster in me angels of liberty
# Querying for:never gonna let you go faith evans
# Found never gonna let you go faith evans
# Similarity Score: 1.0
# Querying for:breathless the corrs
# Found breathless the corrs
# Similarity Score: 1.0
# Querying for:tightrope stevie ray vaughan
# Querying for:ambitionz az a ridah 2pac
# Found ambitionz az a ridah 2pac
# Similarity Score: 1.0
# Querying for:four walls of solitude serpent venom
# Found four walls of solitude serpent venom's
# Similarity Score: 0.972972972972973
# Querying for:dont give up tatanka
# Querying for:dog eat dog adam ant
# Querying for:shes lost control joy division
# Querying for:broke modest mouse
# Found broke modest mouse
# Similarity Score: 1.0
# Querying for:aurora aurora
# Querying for:la cucaracha james last
# Querying for:blood on your hands philip sayce
# Found blood on your hands philip sayce
# Similarity Score: 1.0
# Querying for:together forever rick astley
# Found together forever rick astley
# Similarity Score: 1.0
# Querying for:trizonna trizonna mcclendon
# Found trizonna trizonna mcclendon
# Similarity Score: 1.0
# Querying for:wonderland wonderland
# Querying for:tribulations kommunity fk
# Querying for:heaven paralysed age
# Found heaven paralysed age
# Similarity Score: 1.0
# Querying for:leave it alone broken bells
# Found leave it alone broken bells
# Similarity Score: 1.0
# Querying for:bella stronza marco masini
# Found bella stronza marco masini
# Similarity Score: 1.0
# Querying for:freak on a leash korn
# Found freak on a leash korn
# Similarity Score: 1.0
# Querying for:close to you gerald levert
# Querying for:it doesnt seem right red giant
# Found it doesn't seem right red giant
# Similarity Score: 0.9836065573770492
# Querying for:part of me katy perry
# Found part of me katy perry
# Similarity Score: 1.0
# Querying for:i still havent found what im looking for u2
# Found i still haven't found what i'm looking for u2
# Similarity Score: 0.9772727272727273
# Querying for:kettling bloc party
# Found kettling bloc party
# Similarity Score: 1.0
# Querying for:get lucky daft punk
# Querying for:dont call me baby madison avenue
# Querying for:alone lauren evans
# Querying for:kisses down low kelly rowland
# Found kisses down low kelly rowland
# Similarity Score: 1.0
# Querying for:her shadow projeto renfield
# Querying for:i wanna dance with somebody whitney houston
# Querying for:family show deluxe
# Querying for:the good left undone rise against
# Found the good left undone rise against
# Similarity Score: 1.0
# Querying for:celebration kool & the gang
# Found celebration kool & the gang
# Similarity Score: 1.0
# Querying for:all of me john legend
# Found all of me john legend
# Similarity Score: 1.0
# Querying for:siekiera siekiera
# Found siekiera siekiera
# Similarity Score: 1.0
# Querying for:radio rival sons
# Found radio rival sons
# Similarity Score: 1.0
# Querying for:red taylor swift
# Found red taylor swift
# Similarity Score: 1.0
# Querying for:how great thou art chris rice
# Found how great thou art chris rice
# Similarity Score: 1.0
# Querying for:jungle boogie kool & the gang
# Found jungle boogie kool & the gang
# Similarity Score: 1.0
# Querying for:white mountain genesis
# Querying for:temperature sean paul
# Found temperature sean paul
# Similarity Score: 1.0
# Querying for:phenomenon ll cool j
# Found phenomenon ll cool j
# Similarity Score: 1.0
# Querying for:at my job dead kennedys
# Found at my job dead kennedys
# Similarity Score: 1.0
# Querying for:maria magdalena sandra
# Found maria magdalena sandra
# Similarity Score: 1.0
# Querying for:everyboys right everybodys wrong sham 69
# Querying for:what would you do city high
# Found what would you do? city high
# Similarity Score: 0.9818181818181818
# Querying for:solar sail aleph null
# Querying for:astralplane blues pills
# Found astralplane blues pills
# Similarity Score: 1.0
# Querying for:youre gonna die destroy all monsters
# Found you're gonna die destroy all monsters
# Similarity Score: 0.9863013698630136
# Querying for:aftershock aftershock
# Querying for:a push away from falling razorfade
# Found a push away from falling razorfade
# Similarity Score: 1.0
# Querying for:paranoid ty dolla $ign
# Querying for:good luck charm ohio players
# Found good luck charm ohio players
# Similarity Score: 1.0
# Querying for:badu erykah badu
# Querying for:a mover la colita artie the one man party
# Querying for:disparate youth santigold
# Found disparate youth santigold
# Similarity Score: 1.0
# Querying for:the pains of being pure at heart the pains of being pure at heart
# Querying for:rats disjecta membra
# Querying for:jasmine jai paul
# Querying for:baby baby amy grant
# Found baby, baby amy grant
# Similarity Score: 0.9743589743589743
# Querying for:the answer richie sambora
# Found the answer richie sambora
# Similarity Score: 1.0
# Querying for:i found love deniece williams
# Found i found love deniece williams
# Similarity Score: 1.0
# Querying for:american gothic my terminal and the trip
# Querying for:cinema silent scream
# Found cinema silent scream
# Similarity Score: 1.0
# Querying for:only girl rihanna
# Querying for:for lovers only maxwell
# Querying for:serã¡ las pelotas
# Querying for:have you ever really loved a woman? bryan adams
# Found have you ever really loved a woman? bryan adams
# Similarity Score: 1.0
# Querying for:love of my life anna calvi
# Found love of my life anna calvi
# Similarity Score: 1.0
# Querying for:impossible shontelle
# Querying for:my boo alicia keys
# Querying for:beat biter mc shan
# Querying for:aint nothing like the real thing the jackson 5
# Found ain't nothing like the real thing the jackson 5
# Similarity Score: 0.989247311827957
# Querying for:straight ahead jimi hendrix
# Found straight ahead jimi hendrix
# Similarity Score: 1.0
# Querying for:street life miles jaye
# Found street life miles jaye
# Similarity Score: 1.0
# Querying for:angelia richard marx
# Found angelia richard marx
# Similarity Score: 1.0
# Querying for:watch dead souls rising
# Querying for:ura fever the kills
# Querying for:henny mack wilds
# Found henny mack wilds
# Similarity Score: 1.0
# Querying for:incubus incubus
# Querying for:any love luther vandross
# Found any love luther vandross
# Similarity Score: 1.0
# Querying for:i wanna be with you mandy moore
# Found i wanna be with you mandy moore
# Similarity Score: 1.0
# Querying for:early soundz showtek
# Found early soundz showtek
# Similarity Score: 1.0
# Querying for:turned away chuckii booker
# Found turned away chuckii booker
# Similarity Score: 1.0
# Querying for:another day in paradise phil collins
# Querying for:too close next
# Found too close next
# Similarity Score: 1.0
# Querying for:learn to fly foo fighters
# Found learn to fly foo fighters
# Similarity Score: 1.0
# Querying for:you know my name the union
# Found you know my name the union
# Similarity Score: 1.0
# Querying for:without me fantasia
# Querying for:whales and leeches red fang
# Found whales and leeches red fang
# Similarity Score: 1.0
# Querying for:gloria gloria trevi
# Querying for:trophy siouxsie and the banshees
# Found trophy siouxsie and the banshees
# Similarity Score: 1.0
# Querying for:only god knows why kid rock
# Found only god knows why kid rock
# Similarity Score: 1.0
# Querying for:smells like teen spirit nirvana
# Found smells like teen spirit nirvana
# Similarity Score: 1.0
# Querying for:echoes the rapture
# Found echoes the rapture
# Similarity Score: 1.0
# Querying for:white man in hammersmith palais the clash
# Found (white man) in hammersmith palais the clash
# Similarity Score: 0.9761904761904762
# Querying for:trae trae
# Querying for:black balloon the kills
# Found black balloon the kills
# Similarity Score: 1.0
# Querying for:need your heart adventure club
# Querying for:feel again onerepublic
# Found feel again onerepublic
# Similarity Score: 1.0
# Querying for:dont stop the party pitbull
# Querying for:toy soldiers martika
# Found toy soldiers martika
# Similarity Score: 1.0
# Querying for:body party ciara
# Found body party ciara
# Similarity Score: 1.0
# Querying for:watch me bleed tears for fears
# Found watch me bleed tears for fears
# Similarity Score: 1.0
# Querying for:sons of thunder high on fire
# Querying for:success the merry thoughts
# Querying for:freak like me adina howard
# Found freak like me adina howard
# Similarity Score: 1.0
# Querying for:era era
# Querying for:kill the king megadeth
# Found kill the king megadeth
# Similarity Score: 1.0
# Querying for:the game of love michelle branch
# Querying for:twilight fields dive
# Found twilight fields dive
# Similarity Score: 1.0
# Querying for:bob bob
# Querying for:groovy times the clash
# Found groovy times the clash
# Similarity Score: 1.0
# Querying for:one erykah badu
# Querying for:true romance citizens!
# Found true romance citizens!
# Similarity Score: 1.0
# Querying for:like lead veronica lipgloss and the evil eyes
# Querying for:i lil wayne
# Querying for:rat trap the boomtown rats
# Found rat trap the boomtown rats
# Similarity Score: 1.0
# Querying for:yamanote line el patapsco
# Querying for:darkland awakening subterfuge
# Found darkland awakening subterfuge
# Similarity Score: 1.0
# Querying for:black blizzard slomatics
# Found black blizzard slomatics
# Similarity Score: 1.0
# Querying for:so monkey toys army
# Querying for:slow down showtek
# Found slow down showtek
# Similarity Score: 1.0
# Querying for:radioactive imagine dragons
# Found radioactive imagine dragons
# Similarity Score: 1.0
# Querying for:we are colliders malaise
# Querying for:pass out of existence chimaira
# Found pass out of existence chimaira
# Similarity Score: 1.0
# Querying for:shook ones mobb deep
# Querying for:severity winter severity index
# Found severity winter severity index
# Similarity Score: 1.0
# Querying for:party all the time eddie murphy
# Found party all the time eddie murphy
# Similarity Score: 1.0
# Querying for:ib 10
# Querying for:choking the cherry poe
# Found choking the cherry poe
# Similarity Score: 1.0
# Querying for:2pac 2pac
# Querying for:colours the sisters of mercy
# Querying for:let the love in jeremy hills
# Found let the love in jeremy hills
# Similarity Score: 1.0
# Querying for:more than i can say leo sayer
# Found more than i can say leo sayer
# Similarity Score: 1.0
# Querying for:voices another species
# Querying for:best day of my life american authors
# Found best day of my life american authors
# Similarity Score: 1.0
# Querying for:twilight corpus delicti
# Found twilight corpus delicti
# Similarity Score: 1.0
# Querying for:stay rihanna
# Querying for:listen talib kweli
# Querying for:foxy lady jimi hendrix
# Found foxey lady jimi hendrix
# Similarity Score: 0.9777777777777777
# Querying for:i believe in you neil young
# Found i believe in you neil young
# Similarity Score: 1.0
# Querying for:beautiful day without you röyksopp
# Found beautiful day without you röyksopp
# Similarity Score: 1.0
# Querying for:straight to hell the clash
# Found straight to hell the clash
# Similarity Score: 1.0
# Querying for:outrun dsw
# Querying for:when you walk in the room paul carrack
# Found when you walk in the room paul carrack
# Similarity Score: 1.0
# Querying for:taking over me lawson
# Querying for:happy ending mika
# Found happy ending mika
# Similarity Score: 1.0
# Querying for:cool kids echosmith
# Found cool kids echosmith
# Similarity Score: 1.0
# Querying for:old snake wizard smoke
# Querying for:somebody to love queen
# Querying for:last caress misfits
# Found last caress misfits
# Similarity Score: 1.0
# Querying for:israel siouxsie and the banshees
# Found israel siouxsie and the banshees
# Similarity Score: 1.0
# Querying for:forever live
# Querying for:respect adeva
# Found respect adeva
# Similarity Score: 1.0
# Querying for:neon heart the boomtown rats
# Found neon heart the boomtown rats
# Similarity Score: 1.0
# Querying for:put em up mightyfools
# Querying for:honey hush jerry lee lewis
# Found honey hush jerry lee lewis
# Similarity Score: 1.0
# Querying for:snakecharmer rage against the machine
# Found snakecharmer rage against the machine
# Similarity Score: 1.0
# Querying for:life life
# Querying for:yee deorro
# Querying for:frühling in paris rammstein
# Found frühling in paris rammstein
# Similarity Score: 1.0
# Querying for:bereft of hope exedra
# Querying for:hollaback girl gwen stefani
# Found hollaback girl gwen stefani
# Similarity Score: 1.0
# Querying for:the hammer will bite grand magus
# Found the hammer will bite grand magus
# Similarity Score: 1.0
# Querying for:summer rain carl thomas
# Found summer rain carl thomas
# Similarity Score: 1.0
# Querying for:happy michael jackson
# Querying for:touch defiles death in june
# Found touch defiles death in june
# Similarity Score: 1.0
# Querying for:さすらいの旅人 superfly
# Querying for:cualquier historia la renga
# Found cualquier historia la renga
# Similarity Score: 1.0
# Querying for:dance our tears away kristin amparo
# Querying for:undone weezer
# Querying for:gambler madonna
# Querying for:sometimes love just aint enough patty smyth
# Querying for:simply irresistable robert palmer
# Querying for:where have you been rihanna
# Found where have you been rihanna
# Similarity Score: 1.0
# Querying for:given up linkin park
# Found given up linkin park
# Similarity Score: 1.0
# Querying for:ill see you in my dreams giant
# Found i'll see you in my dreams giant
# Similarity Score: 0.9836065573770492
# Querying for:happy sister hazel
# Found happy sister hazel
# Similarity Score: 1.0
# Querying for:break ya neck busta rhymes
# Found break ya neck busta rhymes
# Similarity Score: 1.0
# Querying for:spectre nosferatu
# Found spectre nosferatu
# Similarity Score: 1.0
# Querying for:walk the backstreets albert castiglia
# Found walk the backstreets albert castiglia
# Similarity Score: 1.0
# Querying for:violence dope
# Found violence dope
# Similarity Score: 1.0
# Querying for:something i need onerepublic
# Found something i need onerepublic
# Similarity Score: 1.0
# Querying for:my lovin en vogue
# Querying for:poison bell biv devoe
# Found poison bell biv devoe
# Similarity Score: 1.0
# Querying for:in da club 50 cent
# Found in da club 50 cent
# Similarity Score: 1.0
# Querying for:yeah yeah bodyrox
# Querying for:when i was your man bruno mars
# Found when i was your man bruno mars
# Similarity Score: 1.0
# Querying for:music joss stone
# Found music joss stone
# Similarity Score: 1.0
# Querying for:one more time daft punk
# Found one more time daft punk
# Similarity Score: 1.0
# Querying for:edenbridge agoria
# Querying for:alone the last dance
# Querying for:tainted love soft cell
# Found tainted love soft cell
# Similarity Score: 1.0
# Querying for:war war
# Querying for:shout shout
# Querying for:why dont you get a job? the offspring
# Found why don't you get a job the offspring
# Similarity Score: 0.972972972972973
# Querying for:flash christian sims
# Querying for:yer blues the beatles
# Querying for:summertime sharon robinson
# Found summertime sharon robinson
# Similarity Score: 1.0
# Querying for:against all odds phil collins
# Querying for:happy pharrell williams
# Found happy pharrell williams
# Similarity Score: 1.0
# Querying for:sins a good mans brother grand funk railroad
# Querying for:rhiannon fleetwood mac
# Found rhiannon fleetwood mac
# Similarity Score: 1.0
# Querying for:fat bottomed girls queen
# Found fat bottomed girls queen
# Similarity Score: 1.0
# Querying for:no one alicia keys
# Found no one alicia keys
# Similarity Score: 1.0
# Querying for:pepper butthole surfers
# Found pepper butthole surfers
# Similarity Score: 1.0
# Querying for:say something a great big world
# Found say something a great big world
# Similarity Score: 1.0
# Querying for:desperate times devildriver
# Found desperate times devildriver
# Similarity Score: 1.0
# Querying for:show me kid ink
# Querying for:back of my hand the jags
# Querying for:4 letter word diggy
# Found 4 letter word diggy
# Similarity Score: 1.0
# Querying for:the night out martin solveig
# Querying for:money pink floyd
# Found money pink floyd
# Similarity Score: 1.0
# Querying for:hold on loosely .38 special
# Found hold on loosely 38 special
# Similarity Score: 0.9811320754716981
# Querying for:alice the sisters of mercy
# Querying for:it wont stop sevyn streeter
# Found it won't stop sevyn streeter
# Similarity Score: 0.9818181818181818
# Querying for:complicated avril lavigne
# Found complicated avril lavigne
# Similarity Score: 1.0
# Querying for:crush david archuleta
# Found crush david archuleta
# Similarity Score: 1.0
# Querying for:music flow
# Querying for:seether seether
# Querying for:venus bananarama
# Found venus bananarama
# Similarity Score: 1.0
# Querying for:dont speak no doubt
# Found don't speak no doubt
# Similarity Score: 0.9743589743589743
# Querying for:spirits alien skull paint
# Querying for:good things the sisters of mercy
# Querying for:dont wanna fall in love jane child
# Found don't wanna fall in love jane child
# Similarity Score: 0.9855072463768116
# Querying for:im so excited the pointer sisters
# Found i'm so excited the pointer sisters
# Similarity Score: 0.9850746268656716
# Querying for:reverend mother the wake
# Querying for:cold as war sevendust
# Found cold as war sevendust
# Similarity Score: 1.0
# Querying for:heroes the script
# Querying for:repetition the fall
# Found repetition the fall
# Similarity Score: 1.0
# Querying for:strange gods, strange altars sheavy
# Found strange gods, strange altars sheavy
# Similarity Score: 1.0
# Querying for:i think were alone now tiffany
# Found i think we're alone now tiffany
# Similarity Score: 0.9836065573770492
# Querying for:kokomo the beach boys
# Found kokomo the beach boys
# Similarity Score: 1.0
# Querying for:drina march james last
# Querying for:young blood the naked and famous
# Found young blood the naked and famous
# Similarity Score: 1.0
# Querying for:brokenhearted karmin
# Found brokenhearted karmin
# Similarity Score: 1.0
# Querying for:dive usher
# Found dive usher
# Similarity Score: 1.0
# Querying for:trees come down fields of the nephilim
# Found trees come down fields of the nephilim
# Similarity Score: 1.0
# Querying for:united states of whatever liam lynch
# Found united states of whatever liam lynch
# Similarity Score: 1.0
# Querying for:500 miles james last
# Querying for:postcards james blunt
# Found postcards james blunt
# Similarity Score: 1.0
# Querying for:love me again john newman
# Found love me again john newman
# Similarity Score: 1.0
# Querying for:backseat freestyle kendrick lamar
# Found backseat freestyle kendrick lamar
# Similarity Score: 1.0
# Querying for:you shook me led zeppelin
# Found you shook me led zeppelin
# Similarity Score: 1.0
# Querying for:dissolution groan
# Found dissolution groan
# Similarity Score: 1.0
# Querying for:my mind aint so open magazine
# Found my mind ain't so open magazine
# Similarity Score: 0.9830508474576272
# Querying for:焔之鳥 陰陽座
# Querying for:sole creation kongh
# Found sole creation kongh
# Similarity Score: 1.0
# Querying for:slipknot slipknot
# Querying for:various artists various artists
# Querying for:little brown jug james last
# Querying for:pandemic escarlatina obsessiva
# Querying for:dawn rising red fang
# Found dawn rising red fang
# Similarity Score: 1.0
# Querying for:black day the merry thoughts
# Found black day the merry thoughts
# Similarity Score: 1.0
# Querying for:cloudless cranes
# Found cloudless cranes
# Similarity Score: 1.0
# Querying for:happy music james last
# Querying for:games claire
# Found games claire
# Similarity Score: 1.0
# Querying for:against the wind bob seger & the silver bullet band
# Querying for:dont always look at the rain howard jones
# Found don't always look at the rain howard jones
# Similarity Score: 0.9879518072289156
# Querying for:umi says mos def
# Found umi says mos def
# Similarity Score: 1.0
# Querying for:all valhalla
# Querying for:my life would suck without you kelly clarkson
# Found my life would suck without you kelly clarkson
# Similarity Score: 1.0
# Querying for:tainted love marilyn manson
# Found tainted love marilyn manson
# Similarity Score: 1.0
# Querying for:when you come around cosmic rough riders
# Querying for:so salt
# Querying for:rawhide link wray
# Found rawhide link wray
# Similarity Score: 1.0
# Querying for:youre a lie slash
# Querying for:cruel summer bananarama
# Found cruel summer bananarama
# Similarity Score: 1.0
# Querying for:dj isaac dj isaac
# Querying for:all the love the outfield
# Found all the love the outfield
# Similarity Score: 1.0
# Querying for:fool james last
# Querying for:for the first time the script
# Found for the first time the script
# Similarity Score: 1.0
# Querying for:police on my back the clash
# Querying for:chant chant
# Querying for:i believe in you twisted sister
# Found i believe in you twisted sister
# Similarity Score: 1.0
# Querying for:glory of love peter cetera
# Found glory of love peter cetera
# Similarity Score: 1.0
# Querying for:volt volt
# Querying for:amor fati washed out
# Found amor fati washed out
# Similarity Score: 1.0
# Querying for:someone simple minds
# Querying for:youre still the one shania twain
# Found you're still the one shania twain
# Similarity Score: 0.9846153846153847
# Querying for:pale divine pale divine
# Querying for:brazil james last
# Querying for:stare the distance obiat
# Querying for:bad girl bad girl
# Querying for:where is the love justin timberlake
# Querying for:telegram sam bauhaus
# Found telegram sam bauhaus
# Similarity Score: 1.0
# Querying for:freelance fiend leaf hound
# Found freelance fiend leaf hound
# Similarity Score: 1.0
# Querying for:tu jam
# Querying for:arabian knights siouxsie and the banshees
# Found arabian knights siouxsie and the banshees
# Similarity Score: 1.0
# Querying for:you never know marly
# Querying for:rich as fuck lil wayne
# Querying for:bad day fuel
# Found bad day fuel
# Similarity Score: 1.0
# Querying for:valley of the dolls generation x
# Querying for:trampled under foot led zeppelin
# Found trampled under foot led zeppelin
# Similarity Score: 1.0
# Querying for:sweet emotion aerosmith
# Found sweet emotion aerosmith
# Similarity Score: 1.0
# Querying for:wrong side of da tracks artifacts
# Found wrong side of da tracks artifacts
# Similarity Score: 1.0
# Querying for:burst magazine
# Found burst magazine
# Similarity Score: 1.0
# Querying for:bodies drowning pool
# Found bodies drowning pool
# Similarity Score: 1.0
# Querying for:religion destructors
# Querying for:youre sixteen ringo starr
# Querying for:what about my broken heart dj bobo
# Found what about my broken heart dj bobo
# Similarity Score: 1.0
# Querying for:fracture fracture
# Querying for:charmaine james last
# Found charmaine james last
# Similarity Score: 1.0
# Querying for:the one dee dee
# Querying for:move in the right direction gossip
# Found move in the right direction gossip
# Similarity Score: 1.0
# Querying for:now paramore
# Found now paramore
# Similarity Score: 1.0
# Querying for:floating downer eternal elysium
# Found floating downer eternal elysium
# Similarity Score: 1.0
# Querying for:everythings gonna be alright sweetbox
# Found everything's gonna be alright sweetbox
# Similarity Score: 0.9866666666666667
# Querying for:change the world eric clapton
# Querying for:memories of rubinstein james last
# Querying for:aint it fun paramore
# Found ain't it fun paramore
# Similarity Score: 0.975609756097561
# Querying for:broken lifehouse
# Found broken lifehouse
# Similarity Score: 1.0
# Querying for:chicago chicago
# Querying for:play jennifer lopez
# Found play jennifer lopez
# Similarity Score: 1.0
# Querying for:teardrops joss stone
# Found teardrops joss stone
# Similarity Score: 1.0
# Querying for:hey brother avicii
# Found hey brother avicii
# Similarity Score: 1.0
# Querying for:la forza mia marco carta
# Found la forza mia marco carta
# Similarity Score: 1.0
# Querying for:touch and go force mds
# Querying for:the outsider a perfect circle
# Found the outsider a perfect circle
# Similarity Score: 1.0
# Querying for:eminence front the who
# Found eminence front the who
# Similarity Score: 1.0
# Querying for:o black
# Querying for:low coldplay
# Found low coldplay
# Similarity Score: 1.0
# Querying for:the man aloe blacc
# Found the man aloe blacc
# Similarity Score: 1.0
# Querying for:go indigo girls
# Found go indigo girls
# Similarity Score: 1.0
# Querying for:river asteroid
# Found river asteroid
# Similarity Score: 1.0
# Querying for:is this love bob marley & the wailers
# Found is this love bob marley & the wailers
# Similarity Score: 1.0
# Querying for:seduction eminem
# Found seduction eminem
# Similarity Score: 1.0
# Querying for:add it up violent femmes
# Found add it up violent femmes
# Similarity Score: 1.0
# Querying for:narcotica the beauty of gemina
# Querying for:cant fight the moonlight leann rimes
# Found can't fight the moonlight leann rimes
# Similarity Score: 0.9863013698630136
# Querying for:need you now lady antebellum
# Found need you now lady antebellum
# Similarity Score: 1.0
# Querying for:fantasma zion
# Found fantasma zion
# Similarity Score: 1.0
# Querying for:down on me jeremih
# Querying for:teenage kicks the undertones
# Found teenage kicks the undertones
# Similarity Score: 1.0
# Querying for:the time of my life david cook
# Found the time of my life david cook
# Similarity Score: 1.0
# Querying for:high horse devil to pay
# Found high horse devil to pay
# Similarity Score: 1.0
# Querying for:senorita justin timberlake
# Found señorita justin timberlake
# Similarity Score: 0.9615384615384616
# Querying for:wiggle it 2 in a room
# Found wiggle it 2 in a room
# Similarity Score: 1.0
# Querying for:last flight out plus one
# Found last flight out plus one
# Similarity Score: 1.0
# Querying for:forever wildstylez
# Querying for:5 miles to empty brownstone
# Querying for:tristan anna calvi
# Found tristan anna calvi
# Similarity Score: 1.0
# Querying for:tiger feet mud
# Found tiger feet mud
# Similarity Score: 1.0
# Querying for:all my life foo fighters
# Found all my life foo fighters
# Similarity Score: 1.0
# Querying for:the wedding diary of dreams
# Found the wedding diary of dreams
# Similarity Score: 1.0
# Querying for:i got a man positive k
# Found i got a man positive k
# Similarity Score: 1.0
# Querying for:the house of wolves bring me the horizon
# Found the house of wolves bring me the horizon
# Similarity Score: 1.0
# Querying for:home phillip phillips
# Found home phillip phillips
# Similarity Score: 1.0
# Querying for:treasure bruno mars
# Found treasure bruno mars
# Similarity Score: 1.0
# Querying for:the final experience ikon
# Found the final experience ikon
# Similarity Score: 1.0
# Querying for:mother mother the veronicas
# Found mother mother the veronicas
# Similarity Score: 1.0
# Querying for:sweet nothing calvin harris
# Querying for:fly butterfly
# Querying for:babydoll mariah carey
# Found babydoll mariah carey
# Similarity Score: 1.0
# Querying for:heaven dj sammy
# Querying for:no excuse black ice
# Querying for:the beautiful dead killing joke
# Querying for:tuxedo junction james last
# Querying for:dont ring me up protex
# Found don't ring me up protex
# Similarity Score: 0.9777777777777777
# Querying for:electric worry clutch
# Found electric worry clutch
# Similarity Score: 1.0
# Querying for:transpose bad suns
# Found transpose bad suns
# Similarity Score: 1.0
# Querying for:instant crush daft punk
# Querying for:dancing in the moonlight toploader
# Found dancing in the moonlight toploader
# Similarity Score: 1.0
# Querying for:i universe
# Querying for:the lamb lies down on broadway genesis
# Querying for:bombers nosferatu
# Found bombers nosferatu
# Similarity Score: 1.0
# Querying for:gallowdance lebanon hanover
# Found gallowdance lebanon hanover
# Similarity Score: 1.0
# Querying for:mirrors of pain deathcamp project
# Found mirrors of pain deathcamp project
# Similarity Score: 1.0
# Querying for:1984 van halen
# Querying for:when the crowds are gone savatage
# Found when the crowds are gone savatage
# Similarity Score: 1.0
# Querying for:athame cough
# ...
# Querying for:still life the horrors
# Found still life the horrors
# Similarity Score: 1.0
# Querying for:slow man sage francis
# Found slow man sage francis
# Similarity Score: 1.0
# Querying for:thirty six karma to burn
# Querying for:scott la rock megamix boogie down productions
# Found scott la rock (megamix) boogie down productions
# Similarity Score: 0.9782608695652174
# Querying for:travelin man bob seger
# Found travelin' man bob seger
# Similarity Score: 0.9777777777777777
# Querying for:song to the siren this mortal coil
# Querying for:death around the corner 2pac
# Found death around the corner 2pac
# Similarity Score: 1.0
# Querying for:everywhere i go lissie
# Found everywhere i go lissie
# Similarity Score: 1.0
# Querying for:crush tonight fat joe
# Querying for:run rudolph run lemmy kilmister
# Querying for:stairway to the stars bill evans
# Querying for:fridays dust doves
# Found friday's dust doves
# Similarity Score: 0.972972972972973
# Querying for:national express the divine comedy
# Found national express the divine comedy
# Similarity Score: 1.0
# Querying for:mess marques houston
# Found mess marques houston
# Similarity Score: 1.0
# Querying for:hold on eric roberson
# Querying for:doin time sublime
# Found doin' time sublime
# Similarity Score: 0.9714285714285714
# Querying for:calm like a bomb rage against the machine
# Found calm like a bomb rage against the machine
# Similarity Score: 1.0
# Querying for:baby the roots
# Querying for:kiss off violent femmes
# Found kiss off violent femmes
# Similarity Score: 1.0
# Querying for:nowhere ride
# Querying for:ナイター do as infinity
# Found ナイター do as infinity
# Similarity Score: 1.0
# Querying for:elevator flo rida
# Querying for:surfing on a rocket air
# Found surfing on a rocket air
# Similarity Score: 1.0
# Querying for:face to the floor chevelle
# Found face to the floor chevelle
# Similarity Score: 1.0
# Querying for:聖者の行進 安藤裕子
# Querying for:champion kanye west
# Found champion kanye west
# Similarity Score: 1.0
# Querying for:friend 橘慶太
# Querying for:do the sinister infectious grooves
# Found do the sinister infectious grooves
# Similarity Score: 1.0
# Querying for:smash the offspring
# Querying for:love dont come ez paul brown
# Found love don't come ez paul brown
# Similarity Score: 0.9824561403508771
# Querying for:paidarion paidarion
# Found paidarion paidarion
# Similarity Score: 1.0
# Querying for:all gods children alabama 3
# Found all god's children alabama 3
# Similarity Score: 0.9818181818181818
# Querying for:hot in here nelly
# Querying for:u better recognize sam sneed
# Querying for:hip hop junkies nice & smooth
# Found hip hop junkies nice & smooth
# Similarity Score: 1.0
# Querying for:kagami choucho
# Querying for:black is black jungle brothers
# Found black is black jungle brothers
# Similarity Score: 1.0
# Querying for:vivir belinda
# Querying for:never going back again fleetwood mac
# Querying for:alles neu peter fox
# Querying for:to lose my life white lies
# Found to lose my life white lies
# Similarity Score: 1.0
# Querying for:fire fall the residents
# Found fire fall the residents
# Similarity Score: 1.0
# Querying for:balaclava arctic monkeys
# Found balaclava arctic monkeys
# Similarity Score: 1.0
# Querying for:10,000 witnesses clutch
# Found 10,000 witnesses clutch
# Similarity Score: 1.0
# Querying for:for you the old women mirthrandir
# Querying for:these things take time the smiths
# Querying for:hypnotised simple minds
# Querying for:dot vs tmr the madd rapper
# Querying for:things i miss the most steely dan
# Found things i miss the most steely dan
# Similarity Score: 1.0
# Querying for:toki no hari perfume
# Found toki no hari perfume
# Similarity Score: 1.0
# Querying for:aurora lucia micarelli
# Found aurora lucia micarelli
# Similarity Score: 1.0
# Querying for:the factory gates kaiser chiefs
# Found the factory gates kaiser chiefs
# Similarity Score: 1.0
# Querying for:mr haze witchcraft
# Found mr. haze witchcraft
# Similarity Score: 0.972972972972973
# Querying for:shine the space brothers
# Querying for:pagliaccio barbarossa
# Found pagliaccio barbarossa
# Similarity Score: 1.0
# Querying for:how long have you known? diiv
# Found how long have you known diiv
# Similarity Score: 0.9824561403508771
# Querying for:into the groove midnight configuration
# Found into the groove midnight configuration
# Similarity Score: 1.0
# Querying for:highway 61 revisited pj harvey
# Found highway '61 revisited pj harvey
# Similarity Score: 0.9836065573770492
# Querying for:サウダージ ポルノグラフィティ
# Querying for:more than love ohio players
# Found more than love ohio players
# Similarity Score: 1.0
# Querying for:keep it real mc ren
# Found keep it real mc ren
# Similarity Score: 1.0
# Querying for:until the last moment yanni
# Found until the last moment yanni
# Similarity Score: 1.0
# Querying for:shes lost control grace jones
# Querying for:empty walls serj tankian
# Found empty walls serj tankian
# Similarity Score: 1.0
# Querying for:eu vi chegar los pericos
# Found eu vi chegar los pericos
# Similarity Score: 1.0
# Querying for:マミーオーケストラ 安藤裕子
# Querying for:highly overrated cowboys & aliens
# Found highly overrated cowboys & aliens
# Similarity Score: 1.0
# Querying for:nice and slow usher
# Querying for:matchstick american royalty
# Found matchstick american royalty
# Similarity Score: 1.0
# Querying for:on the dark side john cafferty
# Found on the dark side john cafferty
# Similarity Score: 1.0
# Querying for:dreaded fist rascalz
# Querying for:roadside roadside
# Querying for:ride on time blackbox
# Querying for:decades love like blood
# Querying for:sausalito summernight diesel
# Found sausalito summernight diesel
# Similarity Score: 1.0
# Querying for:el hombre de tu vida joe veras
# Found el hombre de tu vida joe veras
# Similarity Score: 1.0
# Querying for:noble end lagwagon
# Found noble end lagwagon
# Similarity Score: 1.0
# Querying for:captive sarah harmer
# Found captive sarah harmer
# Similarity Score: 1.0
# Querying for:dance like a monkey new york dolls
# Found dance like a monkey new york dolls
# Similarity Score: 1.0
# Querying for:shakermaker oasis
# Querying for:cry me a river barbra streisand
# Found cry me a river barbra streisand
# Similarity Score: 1.0
# Querying for:lover, you shouldve come over jeff buckley
# Found lover, you should've come over jeff buckley
# Similarity Score: 0.9882352941176471
# Querying for:dear yvette ll cool j
# Found dear yvette ll cool j
# Similarity Score: 1.0
# Querying for:sleep the clock around mates of state
# Found sleep the clock around mates of state
# Similarity Score: 1.0
# Querying for:i wish cher lloyd
# Querying for:like a perpetual funeral my dying bride
# Found like a perpetual funeral my dying bride
# Similarity Score: 1.0
# Querying for:got a love for you jomanda
# Found got a love for you jomanda
# Similarity Score: 1.0
# Querying for:maliblue darius
# Found maliblue darius
# Similarity Score: 1.0
# Querying for:cant stop maroon 5
# Found can't stop maroon 5
# Similarity Score: 0.972972972972973
# Querying for:the best of times sage francis
# Found the best of times sage francis
# Similarity Score: 1.0
# Querying for:ceraikanlah saja t2
# Found ceraikanlah saja t2
# Similarity Score: 1.0
# Querying for:deadlock deadlock
# Querying for:ya cold wanna be wit me utfo
# Found ya cold wanna be wit me utfo
# Similarity Score: 1.0
# Querying for:take it there the roots
# Querying for:i need my girl the national
# Found i need my girl the national
# Similarity Score: 1.0
# Querying for:pejantan tangguh sheila on 7
# Found pejantan tangguh sheila on 7
# Similarity Score: 1.0
# Querying for:flashback calvin harris
# Found flashback calvin harris
# Similarity Score: 1.0
# Querying for:catch kosheen
# Found catch kosheen
# Similarity Score: 1.0
# Querying for:azar saiko
# Querying for:let me love you for tonight kariya
# Found let me love you for tonight kariya
# Similarity Score: 1.0
# Querying for:an owl song canned heat
# Found an owl song canned heat
# Similarity Score: 1.0
# Querying for:non me ne accorgo marco mengoni
# Found non me ne accorgo marco mengoni
# Similarity Score: 1.0
# Querying for:abuelita de batman botellita de jerez
# Querying for:the way we are kate boy
# Found the way we are kate boy
# Similarity Score: 1.0
# Querying for:it could be sunshine love and rockets
# Found it could be sunshine love and rockets
# Similarity Score: 1.0
# Querying for:muezli slo burn
# Querying for:rats in the city the virus
# Found rats in the city the virus
# Similarity Score: 1.0
# Querying for:bittersweet bundle of misery graham coxon
# Querying for:shine like stars cranes
# Found shine like stars cranes
# Similarity Score: 1.0
# Querying for:its not my cross to bear the allman brothers band
# Found it's not my cross to bear the allman brothers band
# Similarity Score: 0.98989898989899
# Querying for:bad vision acid king
# Found bad vision acid king
# Similarity Score: 1.0
# Querying for:take the long way home supertramp
# Found take the long way home supertramp
# Similarity Score: 1.0
# Querying for:bang bang nancy sinatra
# Querying for:mi tierra gloria estefan
# Found mi tierra gloria estefan
# Similarity Score: 1.0
# Querying for:chained the xx
# Found chained the xx
# Similarity Score: 1.0
# Querying for:kamikaze love poets of the fall
# Found kamikaze love poets of the fall
# Similarity Score: 1.0
# Querying for:dream real dreamtide
# Found dream real dreamtide
# Similarity Score: 1.0
# Querying for:put your records on corinne bailey rae
# Found put your records on corinne bailey rae
# Similarity Score: 1.0
# Querying for:lust lustmord
# Querying for:go lil wayne
# Querying for:tírate los tres
# Querying for:problem natalia kills
# Found problem natalia kills
# Similarity Score: 1.0
# Querying for:dari mata sang garuda pee wee gaskins
# Found dari mata sang garuda pee wee gaskins
# Similarity Score: 1.0
# Querying for:flor pã¡lida marc anthony
# Querying for:blackberry molasses mista
# Found blackberry molasses mista
# Similarity Score: 1.0
# Querying for:boys light up australian crawl
# Querying for:brand new cadillac the clash
# Found brand new cadillac the clash
# Similarity Score: 1.0
# Querying for:angels jessica simpson
# Found angels jessica simpson
# Similarity Score: 1.0
# Querying for:i touched a dream the dells
# Found i touched a dream the dells
# Similarity Score: 1.0
# Querying for:scientist coldplay
# Querying for:jaula de oro antony santos
# Querying for:wolf rock guitar wolf
# Found wolf rock guitar wolf
# Similarity Score: 1.0
# Querying for:sun caribou
# Found sun caribou
# Similarity Score: 1.0
# Querying for:bones exposed of mice & men
# Found bones exposed of mice & men
# Similarity Score: 1.0
# Querying for:moonlight sonata ludwig van beethoven
# Querying for:bullet soul switchfoot
# Found bullet soul switchfoot
# Similarity Score: 1.0
# Querying for:never the cure
# Found never the cure
# Similarity Score: 1.0
# Querying for:love is real al jarreau
# Found love is real al jarreau
# Similarity Score: 1.0
# Querying for:roll away your stone mumford & sons
# Found roll away your stone mumford & sons
# Similarity Score: 1.0
# Querying for:bring it here wild sugar
# Found bring it here wild sugar
# Similarity Score: 1.0
# Querying for:dance all night jessica wright
# Querying for:still ydgn of mice & men
# Found still ydg'n of mice & men
# Similarity Score: 0.9795918367346939
# Querying for:stand back the allman brothers band
# Found stand back the allman brothers band
# Similarity Score: 1.0
# Querying for:do it your way mood ii swing
# Found do it your way mood ii swing
# Similarity Score: 1.0
# Querying for:b vistlip
# Found b vistlip
# Similarity Score: 1.0
# Querying for:in those jeans ginuwine
# Found in those jeans ginuwine
# Similarity Score: 1.0
# Querying for:quiero bailar ivy queen
# Found quiero bailar ivy queen
# Similarity Score: 1.0
# Querying for:apple tree erykah badu
# Querying for:running man the running man
# Querying for:savage helloween
# Found savage helloween
# Similarity Score: 1.0
# Querying for:monster static
# Querying for:astounded bran van 3000
# Found astounded bran van 3000
# Similarity Score: 1.0
# Querying for:so hott kid rock
# Found so hott kid rock
# Similarity Score: 1.0
# Querying for:how do you know marc copely
# Found how do you know marc copely
# Similarity Score: 1.0
# Querying for:ritual abuse cough
# Found ritual abuse cough
# Similarity Score: 1.0
# Querying for:días de verano amaral
# Found dias de verano amaral
# Similarity Score: 0.9523809523809523
# Querying for:poor fool ike & tina turner
# Found poor fool ike & tina turner
# Similarity Score: 1.0
# Querying for:stone in love journey
# Found stone in love journey
# Similarity Score: 1.0
# Querying for:chic le freak
# Querying for:i come to you more than i give kim burrell
# Found i come to you more than i give kim burrell
# Similarity Score: 1.0
# Querying for:gin & juice snoop dogg
# Querying for:cross the tracks maceo & the macks
# Querying for:i buried a bone blind pilot
# Found i buried a bone blind pilot
# Similarity Score: 1.0
# Querying for:jfk 2 lax gang starr
# Found jfk 2 lax gang starr
# Similarity Score: 1.0
# Querying for:joy rahsaan patterson
# Found joy rahsaan patterson
# Similarity Score: 1.0
# Querying for:how soon is now the smiths
# Found how soon is now? the smiths
# Similarity Score: 0.9811320754716981
# Querying for:around the bend the asteroids galaxy tour
# Found around the bend the asteroids galaxy tour
# Similarity Score: 1.0
# Querying for:odiame cristian castro
# Querying for:voyage voyage desireless
# Found voyage voyage desireless
# Similarity Score: 1.0
# Querying for:about you xxyyxx
# Found about you xxyyxx
# Similarity Score: 1.0
# Querying for:dont wanna be your girl wet
# Found don't wanna be your girl wet
# Similarity Score: 0.9818181818181818
# Querying for:finders, keepers miriam bryant
# Found finders keepers miriam bryant
# Similarity Score: 0.9830508474576272
# Querying for:exploitation the silent comedy
# Found exploitation the silent comedy
# Similarity Score: 1.0
# Querying for:the planets gustav holst
# Querying for:friend of the devil counting crows
# Found friend of the devil counting crows
# Similarity Score: 1.0
# Querying for:windmills of your mind sting
# Querying for:so help me girl gary barlow
# Found so help me girl gary barlow
# Similarity Score: 1.0
# Querying for:fanfare for the common man emerson, lake & palmer
# Found fanfare for the common man emerson, lake & palmer
# Similarity Score: 1.0
# Querying for:the weekend dave hollister
# Querying for:back where i belong baroness
# Found back where i belong baroness
# Similarity Score: 1.0
# Querying for:ill be brave this christmas big daddy weave
# Found i'll be brave this christmas big daddy weave
# Similarity Score: 0.9885057471264368
# Querying for:favola reale accademia di musica
# Querying for:gold james vincent mcmorrow
# Found gold james vincent mcmorrow
# Similarity Score: 1.0
# Querying for:ativan atlas sound
# Found ativan atlas sound
# Similarity Score: 1.0
# Querying for:the long and winding road the beatles
# Querying for:promises the presets
# Found promises the presets
# Similarity Score: 1.0
# Querying for:one click headshot feed me
# Found one click headshot feed me
# Similarity Score: 1.0
# Querying for:break 4 love raze
# Found break 4 love raze
# Similarity Score: 1.0
# Querying for:ã‚µãƒ¼ã‚¯ãƒ«ã‚²ãƒ¼ãƒ  galileo galilei
# Querying for:syndrome the ellis marsalis trio
# Querying for:into the fourth dimension the orb
# Found into the fourth dimension the orb
# Similarity Score: 1.0
# Querying for:something to talk about bonnie raitt
# Found something to talk about bonnie raitt
# Similarity Score: 1.0
# Querying for:part time suckers boogie down productions
# Found part time suckers boogie down productions
# Similarity Score: 1.0
# Querying for:ken ti
# Querying for:two of us on the run lucius
# Found two of us on the run lucius
# Similarity Score: 1.0
# Querying for:best of me brantley gilbert
# Querying for:pistol slapper blues rory gallagher
# Querying for:send me on my way rusted root
# Found send me on my way rusted root
# Similarity Score: 1.0
# Querying for:we agree yes
# Found we agree yes
# Similarity Score: 1.0
# Querying for:everybodyâ€™s free rozalla
# Querying for:parkers mood james moody
# Found parker's mood james moody
# Similarity Score: 0.9795918367346939
# Querying for:collapse sparta
# Found collapse sparta
# Similarity Score: 1.0
# Querying for:closer to the heart rush
# Found closer to the heart rush
# Similarity Score: 1.0
# Querying for:my rhyme aint done ll cool j
# Found my rhyme ain't done ll cool j
# Similarity Score: 0.9824561403508771
# Querying for:daily reminder leaders of the new school
# Found daily reminder leaders of the new school
# Similarity Score: 1.0
# Querying for:love xo

# %%
for track in final_result:
    db.cultural_tweet.update_many({"track_id": track},
                            {"$set" : {
                                "duration_ms" : final_result[track]
                            }})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-cf8fe3713add> in <module>()
#       2     db.cultural_tweet.update_many({"track_id": track},
#       3                             {"$set" : {
# ----> 4                                 "duration_ms" : final_result[track]
#       5                             }})
#       6
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/pymongo/collection.py in update_many(self, filter, update, upsert, bypass_document_validation, collation)
#     949                                   check_keys=False, multi=True,
#     950                                   bypass_doc_val=bypass_document_validation,
# --> 951                                   collation=collation)
#     952         return UpdateResult(result, self.write_concern.acknowledged)
#     953
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/pymongo/collection.py in _update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation)
#     751                 self.__database.name,
#     752                 command,
# --> 753                 codec_options=self.__write_response_codec_options).copy()
#     754             _check_write_command_response([(0, result)])
#     755             # Add the updatedExisting field for compatibility.
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     422         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     423         except BaseException as error:
# --> 424             self._raise_connection_failure(error)
#     425
#     426     def send_message(self, message, max_doc_size):
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     550             _raise_connection_failure(self.address, error)
#     551         else:
# --> 552             raise error
#     553
#     554     def __eq__(self, other):
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     417                            read_concern,
#     418                            parse_write_concern_error=parse_write_concern_error,
# --> 419                            collation=collation)
#     420         except OperationFailure:
#     421             raise
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation)
#     106     try:
#     107         sock.sendall(msg)
# --> 108         response = receive_message(sock, 1, request_id)
#     109         unpacked = helpers._unpack_response(
#     110             response, codec_options=codec_options)
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/pymongo/network.py in receive_message(sock, operation, request_id, max_message_size)
#     135         sock, operation, request_id, max_message_size=MAX_MESSAGE_SIZE):
#     136     """Receive a raw BSON message or raise socket.error."""
# --> 137     header = _receive_data_on_socket(sock, 16)
#     138     length = _UNPACK_INT(header[:4])[0]
#     139
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     162     while length:
#     163         try:
# --> 164             chunk = sock.recv(length)
#     165         except (IOError, OSError) as exc:
#     166             if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
# Out:
# {'_id': ObjectId('59bfff98ed415cd14d0d27ea'),
#  'artist_id': '029796844c2ca8bc9380dc0a046a6223',
#  'artist_name': 'James Last',
#  'coordinates': None,
#  'created_at': '2014-03-04 11:22:52',
#  'duration_ms': 182693,
#  'geo': None,
#  'hashtags': ['radionomy'],
#  'id': 440794499095478300,
#  'place': None,
#  'source': 'Share.Radionomy.com',
#  'text': '#NowPLaying James Last - Amapola http://t.co/ucxjELVE5a #ListenLive #radionomy #Instrumental',
#  'track_id': '0669adeb25a376ad2219737816de38cf',
#  'track_title': 'Amapola',
#  'tweet_lang': 'sk',
#  'user_id': 'a4efac8193cba040f6019100343944a59d837f1',
#  'user_lang': 'nl',
#  'user_location': '',
#  'user_time_zone': None}

# %%
# Out:
# 23
